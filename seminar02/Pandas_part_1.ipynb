# %% [markdown]
# # Анализ данных с Pandas
# [(**Pan**el **da**ta)](https://pandas.pydata.org/index.html)
# ## Часть 1
#
# ## Cодержание
# * [Настройка отображения](#Настройка отображения)
# * [Чтение данных из файла](#Чтение данных из файла)
# * [Индексация](#Индексация)
# * [Поиск и фильтрация](#Поиск и фильтрация)
# * [Сортировка](#Сортировка)
# * [Переименование](#Переименование)

# %% [markdown]
# **Pandas** — программная библиотека на языке Python для обработки и анализа данных. Работа pandas с данными строится поверх библиотеки NumPy, являющейся инструментом более низкого уровня.
# Библиотека оптимизирована для высокой производительности, наиболее важные части кода написаны на `Cython` и `С`.
#
# Главные структуры данных в `Pandas`:
#  - `DataFrame` (двумерный неоднородный индексированный массив, таблица)
#  - `Series` (одномерный индексированный массив ndarray, столбец/строка)
#  - `Index` – индекс (список названий строк/столбцов)

# %% [markdown]
# **Рекомендуемая литература** (переведена на русский): [Изучаем Pandas](https://drive.google.com/file/d/1EqUUrS81tAHwt_vghs9Hibksa5_GHecI/edit)

# %% [markdown]
# # <a id="Настройка отображения"><span style="color:green"> Настройка отображения </span></a>
# [Документация set_option](https://pandas.pydata.org/pandas-docs/stable/generated/pandas.set_option.html)

# %% [markdown]
# Подключим библиотеку. Стандартаная практика использовать для этой библиотеки сокращение `pd`.

# %%
import pandas as pd

# %%
print(pd.__version__)
# Out:
# 0.22.0

# %% [markdown]
# Настроим опции отображения с помощью функции set_option

# %%
# маскимальное кол-во отображаемых столбцов
pd.set_option('display.max_columns', 13)
# маскимальное кол-во отображаемых строк
pd.set_option('display.max_rows', 10)
# максимальная ширина столбца
pd.set_option('display.max_colwidth', 45)
# максимальная ширина отображения
pd.set_option('display.width', 80)

# %% [markdown]
# # <a id="Чтение данных из файла"><span style="color:green"> Чтение данных из файла </span></a>
#
# [Документация read_csv](https://pandas.pydata.org/pandas-docs/stable/generated/pandas.read_csv.html)

# %% [markdown]
# Табличные данные чаще всего представлены в формате **csv** (**C**omma **S**eparated **V**alues – "значения, разделенные запятыми" (или другим разделителем))

# %% [markdown]
# Загрузим данные. Например мы хотим считать данные из файла csv. Это можно сделать с помощью функции `read_csv` из библиотеки pandas.
# Загрузим таблицу из датасета [FiveThirtyEight Comic Characters Dataset](https://www.kaggle.com/fivethirtyeight/fivethirtyeight-comic-characters-dataset), содержащего данные о парсонажах комиксов Marvel и DC. Множество других датасетов вы можите найти на [kaggle](https://www.kaggle.com/datasets).

# %% [markdown]
# **Описание данных**

# %% [markdown]
# Первичный источник данных [Marvel Wikia](http://marvel.wikia.com/Main_Page)

# %% [markdown]
# Variable | Definition
# ---|---------
# page_id | Уникальный идентификатор персонажа на странице wikia
# name | Имя персонажа
# urlslug | Уникальный url в wikia который ведет к этому персонажу
# ID | Идентификационный статус персонажа (Secret Identity, Public identity, [on marvel only: No Dual Identity])
# ALIGN | Характиристика персонажа (Good, Bad or Neutral)
# EYE | Цвет глаз
# HAIR | Цвет волос
# SEX | Пол персонажа (e.g. Male, Female, etc.)
# GSM | Относится ли персонаж к сексуальному меньшинсву (e.g. Homosexual characters, bisexual characters)
# ALIVE | Жив ли персонаж
# APPEARANCES | Количество появлений персонажа в комиксах (на момент Sep. 2, 2014)
# FIRST APPEARANCE | Месяц и год первого появления персонажа в комиксе
# YEAR | Год первого появления персонажа в комиксе

# %%
data = pd.read_csv("data/marvel-wikia-data.csv", sep=',', dtype={'year': int})

# %% [markdown]
# Часто в read_csv нужно указать:
#    - разделитель полей sep (по умолчанию  ',')
#    - кодировку encoding (например, 'utf8', в Windows часто бывает `'cp1251'`)
#    - разделитель дробей delimiter
#    - usecols - какие колонки нужно загрузить (бывает, что нужны не все, особенно актуально, когда данных много)
#    - index_col - колонка - индекс
#    - dtype - словарь, задающий типы данных для соотв. полей
#    - и т д

# %% [markdown]
# У read_csv множество параметров. Чтобы посмотреть полный список можно воспользоваться справкой: знак вопроса и имя функции или найти описание на [сайте документации](https://pandas.pydata.org/pandas-docs/stable/generated/pandas.read_csv.html)

# %%
pd.read_csv?

# %% [markdown]
# Итак мы считали данные в объект типа DataFrame:

# %%
type(data)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# ## Просмотр данных

# %% [markdown]
# Посмотрим первые 5 строк таблицы

# %%
data.head()
# Out:
#    page_id                                 name  \
# 0     1678            Spider-Man (Peter Parker)
# 1     7139      Captain America (Steven Rogers)
# 2    64786  Wolverine (James \"Logan\" Howlett)
# 3     1868    Iron Man (Anthony \"Tony\" Stark)
# 4     2460                  Thor (Thor Odinson)
#
#                                    urlslug                ID  \
# 0              \/Spider-Man_(Peter_Parker)   Secret Identity
# 1        \/Captain_America_(Steven_Rogers)   Public Identity
# 2  \/Wolverine_(James_%22Logan%22_Howlett)   Public Identity
# 3    \/Iron_Man_(Anthony_%22Tony%22_Stark)   Public Identity
# 4                    \/Thor_(Thor_Odinson)  No Dual Identity
#
#                 ALIGN         EYE        HAIR              SEX  GSM  \
# 0     Good Characters  Hazel Eyes  Brown Hair  Male Characters  NaN
# 1     Good Characters   Blue Eyes  White Hair  Male Characters  NaN
# 2  Neutral Characters   Blue Eyes  Black Hair  Male Characters  NaN
# 3     Good Characters   Blue Eyes  Black Hair  Male Characters  NaN
# 4     Good Characters   Blue Eyes  Blond Hair  Male Characters  NaN
#
#                ALIVE  APPEARANCES FIRST APPEARANCE    Year
# 0  Living Characters       4043.0           Aug-62  1962.0
# 1  Living Characters       3360.0           Mar-41  1941.0
# 2  Living Characters       3061.0           Oct-74  1974.0
# 3  Living Characters       2961.0           Mar-63  1963.0
# 4  Living Characters       2258.0           Nov-50  1950.0

# %% [markdown]
# Если нужно посмотреть первые 10 строк, то нужно просто это явно указать. Не забываем использовать подсказку (навидите курсор на функцию и нажмите shift+tab, это работает только после импорта библиотеки)

# %%
data.head(10)
# Out:
#    page_id                                 name  \
# 0     1678            Spider-Man (Peter Parker)
# 1     7139      Captain America (Steven Rogers)
# 2    64786  Wolverine (James \"Logan\" Howlett)
# 3     1868    Iron Man (Anthony \"Tony\" Stark)
# 4     2460                  Thor (Thor Odinson)
# 5     2458           Benjamin Grimm (Earth-616)
# 6     2166            Reed Richards (Earth-616)
# 7     1833           Hulk (Robert Bruce Banner)
# 8    29481            Scott Summers (Earth-616)
# 9     1837           Jonathan Storm (Earth-616)
#
#                                    urlslug                ID  \
# 0              \/Spider-Man_(Peter_Parker)   Secret Identity
# 1        \/Captain_America_(Steven_Rogers)   Public Identity
# 2  \/Wolverine_(James_%22Logan%22_Howlett)   Public Identity
# 3    \/Iron_Man_(Anthony_%22Tony%22_Stark)   Public Identity
# 4                    \/Thor_(Thor_Odinson)  No Dual Identity
# 5             \/Benjamin_Grimm_(Earth-616)   Public Identity
# 6              \/Reed_Richards_(Earth-616)   Public Identity
# 7             \/Hulk_(Robert_Bruce_Banner)   Public Identity
# 8              \/Scott_Summers_(Earth-616)   Public Identity
# 9             \/Jonathan_Storm_(Earth-616)   Public Identity
#
#                 ALIGN         EYE        HAIR              SEX  GSM  \
# 0     Good Characters  Hazel Eyes  Brown Hair  Male Characters  NaN
# 1     Good Characters   Blue Eyes  White Hair  Male Characters  NaN
# 2  Neutral Characters   Blue Eyes  Black Hair  Male Characters  NaN
# 3     Good Characters   Blue Eyes  Black Hair  Male Characters  NaN
# 4     Good Characters   Blue Eyes  Blond Hair  Male Characters  NaN
# 5     Good Characters   Blue Eyes     No Hair  Male Characters  NaN
# 6     Good Characters  Brown Eyes  Brown Hair  Male Characters  NaN
# 7     Good Characters  Brown Eyes  Brown Hair  Male Characters  NaN
# 8  Neutral Characters  Brown Eyes  Brown Hair  Male Characters  NaN
# 9     Good Characters   Blue Eyes  Blond Hair  Male Characters  NaN
#
#                ALIVE  APPEARANCES FIRST APPEARANCE    Year
# 0  Living Characters       4043.0           Aug-62  1962.0
# 1  Living Characters       3360.0           Mar-41  1941.0
# 2  Living Characters       3061.0           Oct-74  1974.0
# 3  Living Characters       2961.0           Mar-63  1963.0
# 4  Living Characters       2258.0           Nov-50  1950.0
# 5  Living Characters       2255.0           Nov-61  1961.0
# 6  Living Characters       2072.0           Nov-61  1961.0
# 7  Living Characters       2017.0           May-62  1962.0
# 8  Living Characters       1955.0           Sep-63  1963.0
# 9  Living Characters       1934.0           Nov-61  1961.0

# %% [markdown]
# Просмотр последних пяти строк

# %%
data.tail()
# Out:
#        page_id                             name  \
# 16371   657508               Ru'ach (Earth-616)
# 16372   665474  Thane (Thanos' son) (Earth-616)
# 16373   695217    Tinkerer (Skrull) (Earth-616)
# 16374   708811   TK421 (Spiderling) (Earth-616)
# 16375   673702            Yologarch (Earth-616)
#
#                                    urlslug                ID  \
# 16371               \/Ru%27ach_(Earth-616)  No Dual Identity
# 16372  \/Thane_(Thanos%27_son)_(Earth-616)  No Dual Identity
# 16373      \/Tinkerer_(Skrull)_(Earth-616)   Secret Identity
# 16374     \/TK421_(Spiderling)_(Earth-616)   Secret Identity
# 16375              \/Yologarch_(Earth-616)               NaN
#
#                     ALIGN         EYE     HAIR              SEX  GSM  \
# 16371      Bad Characters  Green Eyes  No Hair  Male Characters  NaN
# 16372     Good Characters   Blue Eyes     Bald  Male Characters  NaN
# 16373      Bad Characters  Black Eyes     Bald  Male Characters  NaN
# 16374  Neutral Characters         NaN      NaN  Male Characters  NaN
# 16375      Bad Characters         NaN      NaN              NaN  NaN
#
#                    ALIVE  APPEARANCES FIRST APPEARANCE  Year
# 16371  Living Characters          NaN              NaN   NaN
# 16372  Living Characters          NaN              NaN   NaN
# 16373  Living Characters          NaN              NaN   NaN
# 16374  Living Characters          NaN              NaN   NaN
# 16375  Living Characters          NaN              NaN   NaN

# %% [markdown]
# Случайные n строк

# %%
data.sample(n=5)
# Out:
#       page_id                         name                        urlslug  \
# 6333     1732     George Blair (Earth-616)     \/George_Blair_(Earth-616)
# 3466   425346   Bill (Lobster) (Earth-616)   \/Bill_(Lobster)_(Earth-616)
# 1743    34039  Anne Marie Hoag (Earth-616)  \/Anne_Marie_Hoag_(Earth-616)
# 7217    72934    Maria Russoff (Earth-616)    \/Maria_Russoff_(Earth-616)
# 6033   260744      Papa Shorty (Earth-616)      \/Papa_Shorty_(Earth-616)
#
#                     ID               ALIGN          EYE         HAIR  \
# 6333   Secret Identity      Bad Characters  Purple Eyes  Purple Hair
# 3466               NaN     Good Characters   Green Eyes      No Hair
# 1743  No Dual Identity     Good Characters    Blue Eyes    Grey Hair
# 7217  No Dual Identity  Neutral Characters    Blue Eyes     Red Hair
# 6033   Secret Identity      Bad Characters   Brown Eyes   Black Hair
#
#                     SEX  GSM                ALIVE  APPEARANCES  \
# 6333    Male Characters  NaN    Living Characters          4.0
# 3466    Male Characters  NaN    Living Characters          9.0
# 1743  Female Characters  NaN    Living Characters         21.0
# 7217  Female Characters  NaN  Deceased Characters          3.0
# 6033    Male Characters  NaN  Deceased Characters          4.0
#
#      FIRST APPEARANCE    Year
# 6333           Feb-92  1992.0
# 3466           May-87  1987.0
# 1743           May-89  1989.0
# 7217           Jan-75  1975.0
# 6033           May-74  1974.0

# %% [markdown]
# ### Размер данных

# %%
data.shape
# Out:
# (16376, 13)

# %% [markdown]
# ### Описательные статистики

# %% [markdown]
# Чтобы получить описание по численным данным, можно воспользоваться методом describe()

# %%
data.describe()
# Out:
#              page_id   APPEARANCES          Year
# count   16376.000000  15280.000000  15561.000000
# mean   300232.082377     17.033377   1984.951803
# std    253460.403399     96.372959     19.663571
# min      1025.000000      1.000000   1939.000000
# 25%     28309.500000      1.000000   1974.000000
# 50%    282578.000000      3.000000   1990.000000
# 75%    509077.000000      8.000000   2000.000000
# max    755278.000000   4043.000000   2013.000000

# %% [markdown]
# ###  Информация о данных

# %% [markdown]
# Чтобы посмотреть какие есть признаки, какой у них тип данных в таблице и сколько есть заполненных ячеек, вызовем метод info()

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16376 entries, 0 to 16375
# Data columns (total 13 columns):
# page_id             16376 non-null int64
# name                16376 non-null object
# urlslug             16376 non-null object
# ID                  12606 non-null object
# ALIGN               13564 non-null object
# EYE                 6609 non-null object
# HAIR                12112 non-null object
# SEX                 15522 non-null object
# GSM                 90 non-null object
# ALIVE               16373 non-null object
# APPEARANCES         15280 non-null float64
# FIRST APPEARANCE    15561 non-null object
# Year                15561 non-null float64
# dtypes: float64(2), int64(1), object(10)
# memory usage: 1.6+ MB

# %% [markdown]
# # <a id="Индексация"><span style="color:green"> Индексация </span></a>

# %% [markdown]
# [Документация](https://pandas.pydata.org/pandas-docs/stable/indexing.html)

# %% [markdown]
# Общий подход
# - Индекс + столбцы
#  - элемент  **`data.loc[index, column]`**
#  - подтаблица **`data.loc[list of index, list of columns]`**

# %% [markdown]
# - По нумерации строк и столбцов
#  - элемент  **`data.iloc[i, j]`**
#  - подтаблица **`data.iloc[list of i, list of j]`**

# %% [markdown]
# Наш DataFrame похож на двумерный массив. Как обратиться к его элементам? У DataFrame есть колонки (columns) и индексы (index). columns - это те названия полей, которые вы видите, а index это некий идентификатор строки, по умолчанию если ничего не указано то индекс это просто нумерация строк от 1 до n.

# %%
data.columns
# Out:
# Index(['page_id', 'name', 'urlslug', 'ID', 'ALIGN', 'EYE', 'HAIR', 'SEX',
#        'GSM', 'ALIVE', 'APPEARANCES', 'FIRST APPEARANCE', 'Year'],
#       dtype='object')

# %%
data.index
# Out:
# RangeIndex(start=0, stop=16376, step=1)

# %% [markdown]
# Можно изменить индекс, например на `page_id`.

# %% [markdown]
# ### Изменение идекса

# %% [markdown]
# Метод `set_index` вернет новый DataFrame, с установленным новым индексом, если нужно применить изменения к текущему DataFrame и не возвращать новый, нужно указать `inplace=True`
#
#  ** Важное замечание**
#  Обращайте внимение на то имеет ли тот или иной метод параметр `inplace`, если такой параметр есть, по умолчанию его значение равно `False` и *возвращается новый объект*, при этом текущий не изменяется, если `inplace=True` возваращается `None` (иначе говоря ничего не возвращается) и изменения применяются к текущему объекту!

# %%
data.set_index('page_id', inplace=True)

# %%
data.head(3)
# Out:
#                                         name  \
# page_id
# 1678               Spider-Man (Peter Parker)
# 7139         Captain America (Steven Rogers)
# 64786    Wolverine (James \"Logan\" Howlett)
#
#                                          urlslug               ID  \
# page_id
# 1678                 \/Spider-Man_(Peter_Parker)  Secret Identity
# 7139           \/Captain_America_(Steven_Rogers)  Public Identity
# 64786    \/Wolverine_(James_%22Logan%22_Howlett)  Public Identity
#
#                       ALIGN         EYE        HAIR              SEX  GSM  \
# page_id
# 1678        Good Characters  Hazel Eyes  Brown Hair  Male Characters  NaN
# 7139        Good Characters   Blue Eyes  White Hair  Male Characters  NaN
# 64786    Neutral Characters   Blue Eyes  Black Hair  Male Characters  NaN
#
#                      ALIVE  APPEARANCES FIRST APPEARANCE    Year
# page_id
# 1678     Living Characters       4043.0           Aug-62  1962.0
# 7139     Living Characters       3360.0           Mar-41  1941.0
# 64786    Living Characters       3061.0           Oct-74  1974.0

# %%
data.index
# Out:
# Int64Index([  1678,   7139,  64786,   1868,   2460,   2458,   2166,   1833,
#              29481,   1837,
#             ...
#             643435, 694583, 703892, 660799, 674414, 657508, 665474, 695217,
#             708811, 673702],
#            dtype='int64', name='page_id', length=16376)

# %% [markdown]
# Чтобы обратиться к элементу таблицы пользуясь колонками и индексами нужно воспользоваться методом `loc[index,column]`. Например посмотрим, что хранится в первой строчке в поля `name`:

# %%
data.loc[1678, 'name']
# Out:
# 'Spider-Man (Peter Parker)'

# %% [markdown]
# Но бывает удобно обращаться к элементу по его порядковому номеру, тогда нужно использовать `iloc[i, j]`. Нумерация начитается с 0.

# %%
data.iloc[0, 0]
# Out:
# 'Spider-Man (Peter Parker)'

# %% [markdown]
# ## Транспонирование

# %% [markdown]
# Замена столбцов на строки.

# %%
data.T.head()
# Out:
# page_id                       1678                               7139    \
# name       Spider-Man (Peter Parker)    Captain America (Steven Rogers)
# urlslug  \/Spider-Man_(Peter_Parker)  \/Captain_America_(Steven_Rogers)
# ID                   Secret Identity                    Public Identity
# ALIGN                Good Characters                    Good Characters
# EYE                       Hazel Eyes                          Blue Eyes
#
# page_id                                   64786   \
# name         Wolverine (James \"Logan\" Howlett)
# urlslug  \/Wolverine_(James_%22Logan%22_Howlett)
# ID                               Public Identity
# ALIGN                         Neutral Characters
# EYE                                    Blue Eyes
#
# page_id                                 1868                   2460    \
# name         Iron Man (Anthony \"Tony\" Stark)    Thor (Thor Odinson)
# urlslug  \/Iron_Man_(Anthony_%22Tony%22_Stark)  \/Thor_(Thor_Odinson)
# ID                             Public Identity       No Dual Identity
# ALIGN                          Good Characters        Good Characters
# EYE                                  Blue Eyes              Blue Eyes
#
# page_id                        2458             ...             \
# name       Benjamin Grimm (Earth-616)           ...
# urlslug  \/Benjamin_Grimm_(Earth-616)           ...
# ID                    Public Identity           ...
# ALIGN                 Good Characters           ...
# EYE                         Blue Eyes           ...
#
# page_id                            674414                  657508  \
# name         Phoenix's Shadow (Earth-616)      Ru'ach (Earth-616)
# urlslug  \/Phoenix%27s_Shadow_(Earth-616)  \/Ru%27ach_(Earth-616)
# ID                                    NaN        No Dual Identity
# ALIGN                  Neutral Characters          Bad Characters
# EYE                                   NaN              Green Eyes
#
# page_id                               665474                           695217  \
# name         Thane (Thanos' son) (Earth-616)    Tinkerer (Skrull) (Earth-616)
# urlslug  \/Thane_(Thanos%27_son)_(Earth-616)  \/Tinkerer_(Skrull)_(Earth-616)
# ID                          No Dual Identity                  Secret Identity
# ALIGN                        Good Characters                   Bad Characters
# EYE                                Blue Eyes                       Black Eyes
#
# page_id                            708811                   673702
# name       TK421 (Spiderling) (Earth-616)    Yologarch (Earth-616)
# urlslug  \/TK421_(Spiderling)_(Earth-616)  \/Yologarch_(Earth-616)
# ID                        Secret Identity                      NaN
# ALIGN                  Neutral Characters           Bad Characters
# EYE                                   NaN                      NaN
#
# [5 rows x 16376 columns]

# %%
print(data.T.shape)
print(data.T.columns)
# Out:
# (12, 16376)
# Int64Index([  1678,   7139,  64786,   1868,   2460,   2458,   2166,   1833,
#              29481,   1837,
#             ...
#             643435, 694583, 703892, 660799, 674414, 657508, 665474, 695217,
#             708811, 673702],
#            dtype='int64', name='page_id', length=16376)

# %% [markdown]
# ## pd.Serires

# %% [markdown]
# Каждая колонка в DataFrame это объект Series, у этого объекта тоже есть индексы. Чтобы получить всю колонку 'name' нужно просто указать ее в квадратных скобках.

# %% [markdown]
# **Замечание**
# К колонке можно обращаться через квадратные скобоки или через точку. Предпочтительнее через квадратные скобки, так как обращение через точку похоже на вызов метода, но обращение через точку быстрее набрать.

# %%
data['name'].head()
# Out:
# page_id
# 1678               Spider-Man (Peter Parker)
# 7139         Captain America (Steven Rogers)
# 64786    Wolverine (James \"Logan\" Howlett)
# 1868       Iron Man (Anthony \"Tony\" Stark)
# 2460                     Thor (Thor Odinson)
# Name: name, dtype: object

# %%
data.name.head()
# Out:
# page_id
# 1678               Spider-Man (Peter Parker)
# 7139         Captain America (Steven Rogers)
# 64786    Wolverine (James \"Logan\" Howlett)
# 1868       Iron Man (Anthony \"Tony\" Stark)
# 2460                     Thor (Thor Odinson)
# Name: name, dtype: object

# %%
data['name'].index
# Out:
# Int64Index([  1678,   7139,  64786,   1868,   2460,   2458,   2166,   1833,
#              29481,   1837,
#             ...
#             643435, 694583, 703892, 660799, 674414, 657508, 665474, 695217,
#             708811, 673702],
#            dtype='int64', name='page_id', length=16376)

# %%
type(data['name'])
# Out:
# pandas.core.series.Series

# %% [markdown]
# Чтобы получить строку из данных можно вызвать метод loc указав индекс строки (не НОМЕР) запомните, что loc это обращение по индексу, в частном случае индекс и нумерация совпадают как и в нашем примере. **Строка это тоже Series** у которого индексы - это названия столбцов.

# %%
data.loc[1678]
# Out:
# name                  Spider-Man (Peter Parker)
# urlslug             \/Spider-Man_(Peter_Parker)
# ID                              Secret Identity
# ALIGN                           Good Characters
# EYE                                  Hazel Eyes
#                                ...
# GSM                                         NaN
# ALIVE                         Living Characters
# APPEARANCES                                4043
# FIRST APPEARANCE                         Aug-62
# Year                                       1962
# Name: 1678, Length: 12, dtype: object

# %%
type(data.loc[1678])
# Out:
# pandas.core.series.Series

# %%
data.loc[1678]['name']
# Out:
# 'Spider-Man (Peter Parker)'

# %% [markdown]
# Теперь вы понимаете, что `data.loc[1678]['name']` на самом деле работает так `data.loc[1678]` это `Serires` и потом вы берете индекс 'name' у объекта Series: `data.loc[1678]['name']`

# %% [markdown]
# # <a id="Поиск и фильтрация"><span style="color:green"> Поиск и фильтрация</span></a>

# %% [markdown]
# ### Отбор данных по столбцам

# %% [markdown]
# Например, нас интересуют не все поля\признаки\столбцы, а только некоторый список полей.
# data_sub = data[list_of_cols]

# %%
data_sub = data[['name', 'ALIGN']]

# %%
data_sub.head()
# Out:
#                                         name               ALIGN
# page_id
# 1678               Spider-Man (Peter Parker)     Good Characters
# 7139         Captain America (Steven Rogers)     Good Characters
# 64786    Wolverine (James \"Logan\" Howlett)  Neutral Characters
# 1868       Iron Man (Anthony \"Tony\" Stark)     Good Characters
# 2460                     Thor (Thor Odinson)     Good Characters

# %% [markdown]
# ### Отбор данных по строкам

# %% [markdown]
# Отбор по индексам

# %%
data_sub_row = data.loc[[1678, 2460, 695217]]

# %%
data_sub_row
# Out:
#                                   name                          urlslug  \
# page_id
# 1678         Spider-Man (Peter Parker)      \/Spider-Man_(Peter_Parker)
# 2460               Thor (Thor Odinson)            \/Thor_(Thor_Odinson)
# 695217   Tinkerer (Skrull) (Earth-616)  \/Tinkerer_(Skrull)_(Earth-616)
#
#                        ID            ALIGN         EYE        HAIR  \
# page_id
# 1678      Secret Identity  Good Characters  Hazel Eyes  Brown Hair
# 2460     No Dual Identity  Good Characters   Blue Eyes  Blond Hair
# 695217    Secret Identity   Bad Characters  Black Eyes        Bald
#
#                      SEX  GSM              ALIVE  APPEARANCES  \
# page_id
# 1678     Male Characters  NaN  Living Characters       4043.0
# 2460     Male Characters  NaN  Living Characters       2258.0
# 695217   Male Characters  NaN  Living Characters          NaN
#
#         FIRST APPEARANCE    Year
# page_id
# 1678              Aug-62  1962.0
# 2460              Nov-50  1950.0
# 695217               NaN     NaN

# %% [markdown]
# ### Отбор по строкам и по столбцам

# %% [markdown]
# Индексы + названия колонок, так

# %%
data.loc[[1678, 2460, 695217]][['name', 'ALIGN']]
# Out:
#                                   name            ALIGN
# page_id
# 1678         Spider-Man (Peter Parker)  Good Characters
# 2460               Thor (Thor Odinson)  Good Characters
# 695217   Tinkerer (Skrull) (Earth-616)   Bad Characters

# %% [markdown]
# или так

# %%
data.loc[[1678, 2460, 695217], ['name', 'ALIGN']]
# Out:
#                                   name            ALIGN
# page_id
# 1678         Spider-Man (Peter Parker)  Good Characters
# 2460               Thor (Thor Odinson)  Good Characters
# 695217   Tinkerer (Skrull) (Earth-616)   Bad Characters

# %%
data.loc[:2460, 'name':'HAIR']
# Out:
#                                         name  \
# page_id
# 1678               Spider-Man (Peter Parker)
# 7139         Captain America (Steven Rogers)
# 64786    Wolverine (James \"Logan\" Howlett)
# 1868       Iron Man (Anthony \"Tony\" Stark)
# 2460                     Thor (Thor Odinson)
#
#                                          urlslug                ID  \
# page_id
# 1678                 \/Spider-Man_(Peter_Parker)   Secret Identity
# 7139           \/Captain_America_(Steven_Rogers)   Public Identity
# 64786    \/Wolverine_(James_%22Logan%22_Howlett)   Public Identity
# 1868       \/Iron_Man_(Anthony_%22Tony%22_Stark)   Public Identity
# 2460                       \/Thor_(Thor_Odinson)  No Dual Identity
#
#                       ALIGN         EYE        HAIR
# page_id
# 1678        Good Characters  Hazel Eyes  Brown Hair
# 7139        Good Characters   Blue Eyes  White Hair
# 64786    Neutral Characters   Blue Eyes  Black Hair
# 1868        Good Characters   Blue Eyes  Black Hair
# 2460        Good Characters   Blue Eyes  Blond Hair

# %% [markdown]
# По нумерации строк и столбцов

# %%
data.iloc[[10, 20, 100], [0, 2]]
# Out:
#                             name               ID
# page_id
# 15725    Henry McCoy (Earth-616)  Public Identity
# 1557       Henry Pym (Earth-616)  Public Identity
# 1827           Hogun (Earth-616)  Public Identity

# %% [markdown]
# До 4ой строки (нумерация с 0) и по столбацам с  нулевого до третьего

# %%
data.iloc[:4, 0:3]
# Out:
#                                         name  \
# page_id
# 1678               Spider-Man (Peter Parker)
# 7139         Captain America (Steven Rogers)
# 64786    Wolverine (James \"Logan\" Howlett)
# 1868       Iron Man (Anthony \"Tony\" Stark)
#
#                                          urlslug               ID
# page_id
# 1678                 \/Spider-Man_(Peter_Parker)  Secret Identity
# 7139           \/Captain_America_(Steven_Rogers)  Public Identity
# 64786    \/Wolverine_(James_%22Logan%22_Howlett)  Public Identity
# 1868       \/Iron_Man_(Anthony_%22Tony%22_Stark)  Public Identity

# %% [markdown]
# ### Отбор данных по условию

# %%
data['ALIGN'].unique()
# Out:
# array(['Good Characters', 'Neutral Characters', 'Bad Characters', nan],
#       dtype=object)

# %% [markdown]
# Отберем данные только по нейтральным персонажам. Общая схема отбора такая: data[маска]. Маска - это например Serires со значениями True и False

# %%
mask = (data['ALIGN'] == 'Neutral Characters')

# %%
mask.head()
# Out:
# page_id
# 1678     False
# 7139     False
# 64786     True
# 1868     False
# 2460     False
# Name: ALIGN, dtype: bool

# %%
data_neutral = data[mask]

# %%
data_neutral.head()
# Out:
#                                         name  \
# page_id
# 64786    Wolverine (James \"Logan\" Howlett)
# 29481              Scott Summers (Earth-616)
# 7823              Namor McKenzie (Earth-616)
# 1872          John Jonah Jameson (Earth-616)
# 1671               Nicholas Fury (Earth-616)
#
#                                          urlslug                ID  \
# page_id
# 64786    \/Wolverine_(James_%22Logan%22_Howlett)   Public Identity
# 29481                \/Scott_Summers_(Earth-616)   Public Identity
# 7823                \/Namor_McKenzie_(Earth-616)  No Dual Identity
# 1872            \/John_Jonah_Jameson_(Earth-616)  No Dual Identity
# 1671                 \/Nicholas_Fury_(Earth-616)  No Dual Identity
#
#                       ALIGN         EYE        HAIR              SEX  GSM  \
# page_id
# 64786    Neutral Characters   Blue Eyes  Black Hair  Male Characters  NaN
# 29481    Neutral Characters  Brown Eyes  Brown Hair  Male Characters  NaN
# 7823     Neutral Characters  Green Eyes  Black Hair  Male Characters  NaN
# 1872     Neutral Characters   Blue Eyes  Black Hair  Male Characters  NaN
# 1671     Neutral Characters  Brown Eyes  Brown Hair  Male Characters  NaN
#
#                      ALIVE  APPEARANCES FIRST APPEARANCE    Year
# page_id
# 64786    Living Characters       3061.0           Oct-74  1974.0
# 29481    Living Characters       1955.0           Sep-63  1963.0
# 7823     Living Characters       1528.0              NaN     NaN
# 1872     Living Characters       1266.0           Mar-63  1963.0
# 1671     Living Characters       1137.0           May-63  1963.0

# %% [markdown]
# Можно писать более сложные условия

# %%
data[(data['ALIGN'] == 'Neutral Characters') & (data['EYE'] == 'Brown Eyes')].head()
# Out:
#                               name                      urlslug  \
# page_id
# 29481    Scott Summers (Earth-616)  \/Scott_Summers_(Earth-616)
# 1671     Nicholas Fury (Earth-616)  \/Nicholas_Fury_(Earth-616)
# 1409        Deadpool (Wade Wilson)     \/Deadpool_(Wade_Wilson)
# 1676          Galactus (Earth-616)       \/Galactus_(Earth-616)
# 2382     William Baker (Earth-616)  \/William_Baker_(Earth-616)
#
#                        ID               ALIGN         EYE        HAIR  \
# page_id
# 29481     Public Identity  Neutral Characters  Brown Eyes  Brown Hair
# 1671     No Dual Identity  Neutral Characters  Brown Eyes  Brown Hair
# 1409      Secret Identity  Neutral Characters  Brown Eyes        Bald
# 1676      Secret Identity  Neutral Characters  Brown Eyes     No Hair
# 2382      Secret Identity  Neutral Characters  Brown Eyes  Brown Hair
#
#                      SEX            GSM              ALIVE  APPEARANCES  \
# page_id
# 29481    Male Characters            NaN  Living Characters       1955.0
# 1671     Male Characters            NaN  Living Characters       1137.0
# 1409     Male Characters  Transvestites  Living Characters        500.0
# 1676     Male Characters            NaN  Living Characters        390.0
# 2382     Male Characters            NaN  Living Characters        338.0
#
#         FIRST APPEARANCE    Year
# page_id
# 29481             Sep-63  1963.0
# 1671              May-63  1963.0
# 1409              Feb-91  1991.0
# 1676              Mar-66  1966.0
# 2382              Sep-63  1963.0

# %% [markdown]
# ### Фильтрация по индексам и колонкам с помощью метода `filter`

# %% [markdown]
# [Документация по filter](https://pandas.pydata.org/pandas-docs/stable/generated/pandas.DataFrame.filter.html)

# %% [markdown]
# Отбор по названию колонок

# %%
data.filter(items=['name', 'SEX']).head()
# Out:
#                                         name              SEX
# page_id
# 1678               Spider-Man (Peter Parker)  Male Characters
# 7139         Captain America (Steven Rogers)  Male Characters
# 64786    Wolverine (James \"Logan\" Howlett)  Male Characters
# 1868       Iron Man (Anthony \"Tony\" Stark)  Male Characters
# 2460                     Thor (Thor Odinson)  Male Characters

# %% [markdown]
# Отбор колонок, содержащих 'AL' в названии.

# %%
data.filter(like='AL').head()
# Out:
#                       ALIGN              ALIVE
# page_id
# 1678        Good Characters  Living Characters
# 7139        Good Characters  Living Characters
# 64786    Neutral Characters  Living Characters
# 1868        Good Characters  Living Characters
# 2460        Good Characters  Living Characters

# %% [markdown]
# Отбор по регулярному выражению. Чтобы отбирать по индексам, нужно указать `axis=0`.

# %% [markdown]
# Индексы заканчивающиеся 12 или содержащие 13.

# %%
data.filter(regex='12$|13', axis=0).head()
# Out:
#                                     name                            urlslug  \
# page_id
# 7139     Captain America (Steven Rogers)  \/Captain_America_(Steven_Rogers)
# 1396         Matthew Murdock (Earth-616)      \/Matthew_Murdock_(Earth-616)
# 1346          Piotr Rasputin (Earth-616)       \/Piotr_Rasputin_(Earth-616)
# 2512          Wanda Maximoff (Earth-616)       \/Wanda_Maximoff_(Earth-616)
# 2312            Frank Castle (Earth-616)         \/Frank_Castle_(Earth-616)
#
#                       ID               ALIGN         EYE        HAIR  \
# page_id
# 7139     Public Identity     Good Characters   Blue Eyes  White Hair
# 1396     Public Identity     Good Characters   Blue Eyes    Red Hair
# 1346     Secret Identity     Good Characters   Blue Eyes  Black Hair
# 2512     Public Identity     Good Characters  Green Eyes  Brown Hair
# 2312     Public Identity  Neutral Characters   Blue Eyes  Black Hair
#
#                        SEX  GSM              ALIVE  APPEARANCES  \
# page_id
# 7139       Male Characters  NaN  Living Characters       3360.0
# 1396       Male Characters  NaN  Living Characters       1338.0
# 1346       Male Characters  NaN  Living Characters       1162.0
# 2512     Female Characters  NaN  Living Characters       1161.0
# 2312       Male Characters  NaN  Living Characters        878.0
#
#         FIRST APPEARANCE    Year
# page_id
# 7139              Mar-41  1941.0
# 1396              Apr-64  1964.0
# 1346              May-75  1975.0
# 2512              Mar-64  1964.0
# 2312              Feb-74  1974.0

# %% [markdown]
# # <a id="Сортировка"><span style="color:green"> Сортировка </span></a>

# %% [markdown]
# Данные можно сортировать по столбцу\столбцам и по индексам

# %% [markdown]
# ### Сортировка по индексу

# %% [markdown]
# По умолчанию сортировка всегда в порядке возрастания

# %%
data.sort_index()
# Out:
#                                                  name  \
# page_id
# 1025                         Emil Blonsky (Earth-616)
# 1026                              Absalom (Earth-616)
# 1027                           Carl Creel (Earth-616)
# 1029                         Adam Warlock (Earth-616)
# 1030                        Adam Neramani (Earth-616)
# ...                                               ...
# 755266            Thor (Taskmaster Robot) (Earth-616)
# 755268        Iron Man (Taskmaster Robot) (Earth-616)
# 755271   Captain America (Taskmaster Robot) (Earth...
# 755276     Sub-Mariner (Taskmaster Robot) (Earth-616)
# 755278            Hulk (Taskmaster Robot) (Earth-616)
#
#                                               urlslug                ID  \
# page_id
# 1025                       \/Emil_Blonsky_(Earth-616)   Secret Identity
# 1026                            \/Absalom_(Earth-616)   Secret Identity
# 1027                         \/Carl_Creel_(Earth-616)   Public Identity
# 1029                       \/Adam_Warlock_(Earth-616)  No Dual Identity
# 1030                      \/Adam_Neramani_(Earth-616)   Secret Identity
# ...                                               ...               ...
# 755266          \/Thor_(Taskmaster_Robot)_(Earth-616)   Secret Identity
# 755268      \/Iron_Man_(Taskmaster_Robot)_(Earth-616)   Secret Identity
# 755271   \/Captain_America_(Taskmaster_Robot)_(Ear...   Secret Identity
# 755276   \/Sub-Mariner_(Taskmaster_Robot)_(Earth-616)   Secret Identity
# 755278          \/Hulk_(Taskmaster_Robot)_(Earth-616)   Secret Identity
#
#                    ALIGN         EYE        HAIR                 SEX  GSM  \
# page_id
# 1025      Bad Characters   Blue Eyes  Blond Hair     Male Characters  NaN
# 1026                 NaN   Blue Eyes  Blond Hair     Male Characters  NaN
# 1027      Bad Characters   Blue Eyes        Bald     Male Characters  NaN
# 1029     Good Characters  White Eyes   Gold Hair     Male Characters  NaN
# 1030     Good Characters   Blue Eyes  Blond Hair     Male Characters  NaN
# ...                  ...         ...         ...                 ...  ...
# 755266    Bad Characters         NaN  Blond Hair     Male Characters  NaN
# 755268    Bad Characters         NaN         NaN  Agender Characters  NaN
# 755271    Bad Characters         NaN         NaN     Male Characters  NaN
# 755276    Bad Characters         NaN         NaN     Male Characters  NaN
# 755278    Bad Characters         NaN         NaN     Male Characters  NaN
#
#                        ALIVE  APPEARANCES FIRST APPEARANCE    Year
# page_id
# 1025       Living Characters        115.0           Apr-67  1967.0
# 1026     Deceased Characters          6.0           May-92  1992.0
# 1027       Living Characters        202.0           Apr-64  1964.0
# 1029       Living Characters        252.0           Sep-67  1967.0
# 1030       Living Characters         21.0           Oct-93  1993.0
# ...                      ...          ...              ...     ...
# 755266     Living Characters          1.0           Oct-98  1998.0
# 755268     Living Characters          1.0           Oct-98  1998.0
# 755271     Living Characters          1.0           Oct-98  1998.0
# 755276     Living Characters          1.0           Oct-98  1998.0
# 755278     Living Characters          1.0           Oct-98  1998.0
#
# [16376 rows x 12 columns]

# %% [markdown]
# Чтобы изменить порядок сортировки нужно указать `ascending=False`

# %%
data.sort_index(ascending=False)
# Out:
#                                                  name  \
# page_id
# 755278            Hulk (Taskmaster Robot) (Earth-616)
# 755276     Sub-Mariner (Taskmaster Robot) (Earth-616)
# 755271   Captain America (Taskmaster Robot) (Earth...
# 755268        Iron Man (Taskmaster Robot) (Earth-616)
# 755266            Thor (Taskmaster Robot) (Earth-616)
# ...                                               ...
# 1030                        Adam Neramani (Earth-616)
# 1029                         Adam Warlock (Earth-616)
# 1027                           Carl Creel (Earth-616)
# 1026                              Absalom (Earth-616)
# 1025                         Emil Blonsky (Earth-616)
#
#                                               urlslug                ID  \
# page_id
# 755278          \/Hulk_(Taskmaster_Robot)_(Earth-616)   Secret Identity
# 755276   \/Sub-Mariner_(Taskmaster_Robot)_(Earth-616)   Secret Identity
# 755271   \/Captain_America_(Taskmaster_Robot)_(Ear...   Secret Identity
# 755268      \/Iron_Man_(Taskmaster_Robot)_(Earth-616)   Secret Identity
# 755266          \/Thor_(Taskmaster_Robot)_(Earth-616)   Secret Identity
# ...                                               ...               ...
# 1030                      \/Adam_Neramani_(Earth-616)   Secret Identity
# 1029                       \/Adam_Warlock_(Earth-616)  No Dual Identity
# 1027                         \/Carl_Creel_(Earth-616)   Public Identity
# 1026                            \/Absalom_(Earth-616)   Secret Identity
# 1025                       \/Emil_Blonsky_(Earth-616)   Secret Identity
#
#                    ALIGN         EYE        HAIR                 SEX  GSM  \
# page_id
# 755278    Bad Characters         NaN         NaN     Male Characters  NaN
# 755276    Bad Characters         NaN         NaN     Male Characters  NaN
# 755271    Bad Characters         NaN         NaN     Male Characters  NaN
# 755268    Bad Characters         NaN         NaN  Agender Characters  NaN
# 755266    Bad Characters         NaN  Blond Hair     Male Characters  NaN
# ...                  ...         ...         ...                 ...  ...
# 1030     Good Characters   Blue Eyes  Blond Hair     Male Characters  NaN
# 1029     Good Characters  White Eyes   Gold Hair     Male Characters  NaN
# 1027      Bad Characters   Blue Eyes        Bald     Male Characters  NaN
# 1026                 NaN   Blue Eyes  Blond Hair     Male Characters  NaN
# 1025      Bad Characters   Blue Eyes  Blond Hair     Male Characters  NaN
#
#                        ALIVE  APPEARANCES FIRST APPEARANCE    Year
# page_id
# 755278     Living Characters          1.0           Oct-98  1998.0
# 755276     Living Characters          1.0           Oct-98  1998.0
# 755271     Living Characters          1.0           Oct-98  1998.0
# 755268     Living Characters          1.0           Oct-98  1998.0
# 755266     Living Characters          1.0           Oct-98  1998.0
# ...                      ...          ...              ...     ...
# 1030       Living Characters         21.0           Oct-93  1993.0
# 1029       Living Characters        252.0           Sep-67  1967.0
# 1027       Living Characters        202.0           Apr-64  1964.0
# 1026     Deceased Characters          6.0           May-92  1992.0
# 1025       Living Characters        115.0           Apr-67  1967.0
#
# [16376 rows x 12 columns]

# %% [markdown]
# Сортировка по названию столбцов

# %%
data.sort_index(axis=1)
# Out:
#                       ALIGN              ALIVE  APPEARANCES         EYE  \
# page_id
# 1678        Good Characters  Living Characters       4043.0  Hazel Eyes
# 7139        Good Characters  Living Characters       3360.0   Blue Eyes
# 64786    Neutral Characters  Living Characters       3061.0   Blue Eyes
# 1868        Good Characters  Living Characters       2961.0   Blue Eyes
# 2460        Good Characters  Living Characters       2258.0   Blue Eyes
# ...                     ...                ...          ...         ...
# 657508       Bad Characters  Living Characters          NaN  Green Eyes
# 665474      Good Characters  Living Characters          NaN   Blue Eyes
# 695217       Bad Characters  Living Characters          NaN  Black Eyes
# 708811   Neutral Characters  Living Characters          NaN         NaN
# 673702       Bad Characters  Living Characters          NaN         NaN
#
#         FIRST APPEARANCE  GSM        HAIR                ID              SEX  \
# page_id
# 1678              Aug-62  NaN  Brown Hair   Secret Identity  Male Characters
# 7139              Mar-41  NaN  White Hair   Public Identity  Male Characters
# 64786             Oct-74  NaN  Black Hair   Public Identity  Male Characters
# 1868              Mar-63  NaN  Black Hair   Public Identity  Male Characters
# 2460              Nov-50  NaN  Blond Hair  No Dual Identity  Male Characters
# ...                  ...  ...         ...               ...              ...
# 657508               NaN  NaN     No Hair  No Dual Identity  Male Characters
# 665474               NaN  NaN        Bald  No Dual Identity  Male Characters
# 695217               NaN  NaN        Bald   Secret Identity  Male Characters
# 708811               NaN  NaN         NaN   Secret Identity  Male Characters
# 673702               NaN  NaN         NaN               NaN              NaN
#
#            Year                                 name  \
# page_id
# 1678     1962.0            Spider-Man (Peter Parker)
# 7139     1941.0      Captain America (Steven Rogers)
# 64786    1974.0  Wolverine (James \"Logan\" Howlett)
# 1868     1963.0    Iron Man (Anthony \"Tony\" Stark)
# 2460     1950.0                  Thor (Thor Odinson)
# ...         ...                                  ...
# 657508      NaN                   Ru'ach (Earth-616)
# 665474      NaN      Thane (Thanos' son) (Earth-616)
# 695217      NaN        Tinkerer (Skrull) (Earth-616)
# 708811      NaN       TK421 (Spiderling) (Earth-616)
# 673702      NaN                Yologarch (Earth-616)
#
#                                          urlslug
# page_id
# 1678                 \/Spider-Man_(Peter_Parker)
# 7139           \/Captain_America_(Steven_Rogers)
# 64786    \/Wolverine_(James_%22Logan%22_Howlett)
# 1868       \/Iron_Man_(Anthony_%22Tony%22_Stark)
# 2460                       \/Thor_(Thor_Odinson)
# ...                                          ...
# 657508                    \/Ru%27ach_(Earth-616)
# 665474       \/Thane_(Thanos%27_son)_(Earth-616)
# 695217           \/Tinkerer_(Skrull)_(Earth-616)
# 708811          \/TK421_(Spiderling)_(Earth-616)
# 673702                   \/Yologarch_(Earth-616)
#
# [16376 rows x 12 columns]

# %% [markdown]
# ### Сортировка по столбцу

# %%
data.sort_values('Year')[['name', 'Year']].dropna()
# Out:
#                                                  name    Year
# page_id
# 645438              Mr. Harris' Secretary (Earth-616)  1939.0
# 1836                Human Torch (Android) (Earth-616)  1939.0
# 331151                             N'Jaga (Earth-616)  1939.0
# 642960                        Tim Roberts (Earth-616)  1939.0
# 727086                Tex (Masked Raider) (Earth-616)  1939.0
# ...                                               ...     ...
# 687367          Pestilence (11th Century) (Earth-616)  2013.0
# 670481   Non-Newtonian Annie (Legion Personality) ...  2013.0
# 579240                     Natalie Turner (Earth-616)  2013.0
# 595507                  Uriel Worthington (Earth-616)  2013.0
# 611134                       Mole Monster (Earth-616)  2013.0
#
# [15561 rows x 2 columns]

# %% [markdown]
# Сортировка по столбцам
#
# Не смущайтесь `dropna` о нем поговорим во второй части.

# %%
data.sort_values(['Year', 'FIRST APPEARANCE'])[['ID', 'name', 'Year', 'FIRST APPEARANCE']].dropna()
# Out:
#                        ID                                name    Year  \
# page_id
# 438715   No Dual Identity            Pete Johnson (Earth-616)  1939.0
# 639362   No Dual Identity                 Drayson (Earth-616)  1939.0
# 743298   No Dual Identity                   Josef (Earth-616)  1939.0
# 461528   No Dual Identity                  Bardak (Earth-616)  1939.0
# 437129   No Dual Identity            Blackie Ross (Earth-616)  1939.0
# ...                   ...                                 ...     ...
# 623767   No Dual Identity            Nina Ambrose (Earth-616)  2013.0
# 625357    Secret Identity                Morrigon (Earth-616)  2013.0
# 595516    Public Identity        Mister Moctezuma (Earth-616)  2013.0
# 637723   No Dual Identity  William Henry Harrison (Earth-616)  2013.0
# 611134    Secret Identity            Mole Monster (Earth-616)  2013.0
#
#         FIRST APPEARANCE
# page_id
# 438715            Dec-39
# 639362            Dec-39
# 743298            Dec-39
# 461528            Dec-39
# 437129            Dec-39
# ...                  ...
# 623767            May-13
# 625357            May-13
# 595516            May-13
# 637723            May-13
# 611134            May-13
#
# [11959 rows x 4 columns]

# %% [markdown]
# # <a id="Переименование"><span style="color:green">Переименование</span></a>

# %% [markdown]
# [Документация по rename](https://pandas.pydata.org/pandas-docs/stable/generated/pandas.DataFrame.rename.html)

# %% [markdown]
# Переименование столбцов по словарю

# %%
data.rename(columns={'name':'full_name', 'APPEARANCES': 'cnt_appearance'})
# Out:
#                                    full_name  \
# page_id
# 1678               Spider-Man (Peter Parker)
# 7139         Captain America (Steven Rogers)
# 64786    Wolverine (James \"Logan\" Howlett)
# 1868       Iron Man (Anthony \"Tony\" Stark)
# 2460                     Thor (Thor Odinson)
# ...                                      ...
# 657508                    Ru'ach (Earth-616)
# 665474       Thane (Thanos' son) (Earth-616)
# 695217         Tinkerer (Skrull) (Earth-616)
# 708811        TK421 (Spiderling) (Earth-616)
# 673702                 Yologarch (Earth-616)
#
#                                          urlslug                ID  \
# page_id
# 1678                 \/Spider-Man_(Peter_Parker)   Secret Identity
# 7139           \/Captain_America_(Steven_Rogers)   Public Identity
# 64786    \/Wolverine_(James_%22Logan%22_Howlett)   Public Identity
# 1868       \/Iron_Man_(Anthony_%22Tony%22_Stark)   Public Identity
# 2460                       \/Thor_(Thor_Odinson)  No Dual Identity
# ...                                          ...               ...
# 657508                    \/Ru%27ach_(Earth-616)  No Dual Identity
# 665474       \/Thane_(Thanos%27_son)_(Earth-616)  No Dual Identity
# 695217           \/Tinkerer_(Skrull)_(Earth-616)   Secret Identity
# 708811          \/TK421_(Spiderling)_(Earth-616)   Secret Identity
# 673702                   \/Yologarch_(Earth-616)               NaN
#
#                       ALIGN         EYE        HAIR              SEX  GSM  \
# page_id
# 1678        Good Characters  Hazel Eyes  Brown Hair  Male Characters  NaN
# 7139        Good Characters   Blue Eyes  White Hair  Male Characters  NaN
# 64786    Neutral Characters   Blue Eyes  Black Hair  Male Characters  NaN
# 1868        Good Characters   Blue Eyes  Black Hair  Male Characters  NaN
# 2460        Good Characters   Blue Eyes  Blond Hair  Male Characters  NaN
# ...                     ...         ...         ...              ...  ...
# 657508       Bad Characters  Green Eyes     No Hair  Male Characters  NaN
# 665474      Good Characters   Blue Eyes        Bald  Male Characters  NaN
# 695217       Bad Characters  Black Eyes        Bald  Male Characters  NaN
# 708811   Neutral Characters         NaN         NaN  Male Characters  NaN
# 673702       Bad Characters         NaN         NaN              NaN  NaN
#
#                      ALIVE  cnt_appearance FIRST APPEARANCE    Year
# page_id
# 1678     Living Characters          4043.0           Aug-62  1962.0
# 7139     Living Characters          3360.0           Mar-41  1941.0
# 64786    Living Characters          3061.0           Oct-74  1974.0
# 1868     Living Characters          2961.0           Mar-63  1963.0
# 2460     Living Characters          2258.0           Nov-50  1950.0
# ...                    ...             ...              ...     ...
# 657508   Living Characters             NaN              NaN     NaN
# 665474   Living Characters             NaN              NaN     NaN
# 695217   Living Characters             NaN              NaN     NaN
# 708811   Living Characters             NaN              NaN     NaN
# 673702   Living Characters             NaN              NaN     NaN
#
# [16376 rows x 12 columns]

# %% [markdown]
# Переведем все колонки в нижний регистр

# %%
data.rename(columns=str.lower)
# Out:
#                                         name  \
# page_id
# 1678               Spider-Man (Peter Parker)
# 7139         Captain America (Steven Rogers)
# 64786    Wolverine (James \"Logan\" Howlett)
# 1868       Iron Man (Anthony \"Tony\" Stark)
# 2460                     Thor (Thor Odinson)
# ...                                      ...
# 657508                    Ru'ach (Earth-616)
# 665474       Thane (Thanos' son) (Earth-616)
# 695217         Tinkerer (Skrull) (Earth-616)
# 708811        TK421 (Spiderling) (Earth-616)
# 673702                 Yologarch (Earth-616)
#
#                                          urlslug                id  \
# page_id
# 1678                 \/Spider-Man_(Peter_Parker)   Secret Identity
# 7139           \/Captain_America_(Steven_Rogers)   Public Identity
# 64786    \/Wolverine_(James_%22Logan%22_Howlett)   Public Identity
# 1868       \/Iron_Man_(Anthony_%22Tony%22_Stark)   Public Identity
# 2460                       \/Thor_(Thor_Odinson)  No Dual Identity
# ...                                          ...               ...
# 657508                    \/Ru%27ach_(Earth-616)  No Dual Identity
# 665474       \/Thane_(Thanos%27_son)_(Earth-616)  No Dual Identity
# 695217           \/Tinkerer_(Skrull)_(Earth-616)   Secret Identity
# 708811          \/TK421_(Spiderling)_(Earth-616)   Secret Identity
# 673702                   \/Yologarch_(Earth-616)               NaN
#
#                       align         eye        hair              sex  gsm  \
# page_id
# 1678        Good Characters  Hazel Eyes  Brown Hair  Male Characters  NaN
# 7139        Good Characters   Blue Eyes  White Hair  Male Characters  NaN
# 64786    Neutral Characters   Blue Eyes  Black Hair  Male Characters  NaN
# 1868        Good Characters   Blue Eyes  Black Hair  Male Characters  NaN
# 2460        Good Characters   Blue Eyes  Blond Hair  Male Characters  NaN
# ...                     ...         ...         ...              ...  ...
# 657508       Bad Characters  Green Eyes     No Hair  Male Characters  NaN
# 665474      Good Characters   Blue Eyes        Bald  Male Characters  NaN
# 695217       Bad Characters  Black Eyes        Bald  Male Characters  NaN
# 708811   Neutral Characters         NaN         NaN  Male Characters  NaN
# 673702       Bad Characters         NaN         NaN              NaN  NaN
#
#                      alive  appearances first appearance    year
# page_id
# 1678     Living Characters       4043.0           Aug-62  1962.0
# 7139     Living Characters       3360.0           Mar-41  1941.0
# 64786    Living Characters       3061.0           Oct-74  1974.0
# 1868     Living Characters       2961.0           Mar-63  1963.0
# 2460     Living Characters       2258.0           Nov-50  1950.0
# ...                    ...          ...              ...     ...
# 657508   Living Characters          NaN              NaN     NaN
# 665474   Living Characters          NaN              NaN     NaN
# 695217   Living Characters          NaN              NaN     NaN
# 708811   Living Characters          NaN              NaN     NaN
# 673702   Living Characters          NaN              NaN     NaN
#
# [16376 rows x 12 columns]

# %% [markdown]
# Как вы видите, можно заменять имена столбцов, применяя к названию некоторую функцию

# %%
data.rename(columns=lambda col: col.lower() + '_' + 'marvel')
# Out:
#                                  name_marvel  \
# page_id
# 1678               Spider-Man (Peter Parker)
# 7139         Captain America (Steven Rogers)
# 64786    Wolverine (James \"Logan\" Howlett)
# 1868       Iron Man (Anthony \"Tony\" Stark)
# 2460                     Thor (Thor Odinson)
# ...                                      ...
# 657508                    Ru'ach (Earth-616)
# 665474       Thane (Thanos' son) (Earth-616)
# 695217         Tinkerer (Skrull) (Earth-616)
# 708811        TK421 (Spiderling) (Earth-616)
# 673702                 Yologarch (Earth-616)
#
#                                   urlslug_marvel         id_marvel  \
# page_id
# 1678                 \/Spider-Man_(Peter_Parker)   Secret Identity
# 7139           \/Captain_America_(Steven_Rogers)   Public Identity
# 64786    \/Wolverine_(James_%22Logan%22_Howlett)   Public Identity
# 1868       \/Iron_Man_(Anthony_%22Tony%22_Stark)   Public Identity
# 2460                       \/Thor_(Thor_Odinson)  No Dual Identity
# ...                                          ...               ...
# 657508                    \/Ru%27ach_(Earth-616)  No Dual Identity
# 665474       \/Thane_(Thanos%27_son)_(Earth-616)  No Dual Identity
# 695217           \/Tinkerer_(Skrull)_(Earth-616)   Secret Identity
# 708811          \/TK421_(Spiderling)_(Earth-616)   Secret Identity
# 673702                   \/Yologarch_(Earth-616)               NaN
#
#                align_marvel  eye_marvel hair_marvel       sex_marvel  \
# page_id
# 1678        Good Characters  Hazel Eyes  Brown Hair  Male Characters
# 7139        Good Characters   Blue Eyes  White Hair  Male Characters
# 64786    Neutral Characters   Blue Eyes  Black Hair  Male Characters
# 1868        Good Characters   Blue Eyes  Black Hair  Male Characters
# 2460        Good Characters   Blue Eyes  Blond Hair  Male Characters
# ...                     ...         ...         ...              ...
# 657508       Bad Characters  Green Eyes     No Hair  Male Characters
# 665474      Good Characters   Blue Eyes        Bald  Male Characters
# 695217       Bad Characters  Black Eyes        Bald  Male Characters
# 708811   Neutral Characters         NaN         NaN  Male Characters
# 673702       Bad Characters         NaN         NaN              NaN
#
#         gsm_marvel       alive_marvel  appearances_marvel  \
# page_id
# 1678           NaN  Living Characters              4043.0
# 7139           NaN  Living Characters              3360.0
# 64786          NaN  Living Characters              3061.0
# 1868           NaN  Living Characters              2961.0
# 2460           NaN  Living Characters              2258.0
# ...            ...                ...                 ...
# 657508         NaN  Living Characters                 NaN
# 665474         NaN  Living Characters                 NaN
# 695217         NaN  Living Characters                 NaN
# 708811         NaN  Living Characters                 NaN
# 673702         NaN  Living Characters                 NaN
#
#         first appearance_marvel  year_marvel
# page_id
# 1678                     Aug-62       1962.0
# 7139                     Mar-41       1941.0
# 64786                    Oct-74       1974.0
# 1868                     Mar-63       1963.0
# 2460                     Nov-50       1950.0
# ...                         ...          ...
# 657508                      NaN          NaN
# 665474                      NaN          NaN
# 695217                      NaN          NaN
# 708811                      NaN          NaN
# 673702                      NaN          NaN
#
# [16376 rows x 12 columns]

# %% [markdown]
# Продолжение ищи во второй части! =)
