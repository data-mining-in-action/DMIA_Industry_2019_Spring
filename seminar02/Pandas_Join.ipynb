# %% [markdown]
# # Соединение таблиц в Pandas
# ## Merge, join, and concatenate

# %% [markdown]
# Соединения двух или более таблиц данных по совпадающему условию.
# Подробнее в [документации](https://pandas.pydata.org/pandas-docs/stable/merging.html)

# %%
import pandas as pd

# %% [markdown]
# Создадим три таблицы для демонстрации

# %% [markdown]
# ### Первая таблица

# %%
raw_data = {
        'subject_id': ['1', '2', '3', '4', '5'],
        'first_name': ['Alex', 'Amy', 'Allen', 'Alice', 'Ayoung'], 
        'last_name': ['Anderson', 'Ackerman', 'Ali', 'Aoni', 'Atiches']}
df_a = pd.DataFrame(raw_data, columns = ['subject_id', 'first_name', 'last_name'])
df_a
# Out:
#   subject_id first_name last_name
# 0          1       Alex  Anderson
# 1          2        Amy  Ackerman
# 2          3      Allen       Ali
# 3          4      Alice      Aoni
# 4          5     Ayoung   Atiches

# %% [markdown]
# ### Вторая таблица

# %%
raw_data = {
        'subject_id': ['4', '5', '6', '7', '8'],
        'first_name': ['Billy', 'Brian', 'Bran', 'Bryce', 'Betty'], 
        'last_name': ['Bonder', 'Black', 'Balwner', 'Brice', 'Btisan']}
df_b = pd.DataFrame(raw_data, columns = ['subject_id', 'first_name', 'last_name'])
df_b
# Out:
#   subject_id first_name last_name
# 0          4      Billy    Bonder
# 1          5      Brian     Black
# 2          6       Bran   Balwner
# 3          7      Bryce     Brice
# 4          8      Betty    Btisan

# %% [markdown]
# ### Третья таблица

# %%
raw_data = {
        'subject_id': ['1', '2', '3', '4', '5', '7', '8', '9', '10', '11'],
        'test_id': [51, 15, 15, 61, 16, 14, 15, 1, 61, 16]}
df_n = pd.DataFrame(raw_data, columns = ['subject_id','test_id'])
df_n
# Out:
#   subject_id  test_id
# 0          1       51
# 1          2       15
# 2          3       15
# 3          4       61
# 4          5       16
# 5          7       14
# 6          8       15
# 7          9        1
# 8         10       61
# 9         11       16

# %% [markdown]
# # Join по строчкам

# %%
df_new = pd.concat([df_a, df_b], ignore_index=False)
df_new
# Out:
#   subject_id first_name last_name
# 0          1       Alex  Anderson
# 1          2        Amy  Ackerman
# 2          3      Allen       Ali
# 3          4      Alice      Aoni
# 4          5     Ayoung   Atiches
# 0          4      Billy    Bonder
# 1          5      Brian     Black
# 2          6       Bran   Balwner
# 3          7      Bryce     Brice
# 4          8      Betty    Btisan

# %%
df_new = pd.concat([df_a, df_b], ignore_index=True)
df_new
# Out:
#   subject_id first_name last_name
# 0          1       Alex  Anderson
# 1          2        Amy  Ackerman
# 2          3      Allen       Ali
# 3          4      Alice      Aoni
# 4          5     Ayoung   Atiches
# 5          4      Billy    Bonder
# 6          5      Brian     Black
# 7          6       Bran   Balwner
# 8          7      Bryce     Brice
# 9          8      Betty    Btisan

# %% [markdown]
# # Join по столбцам

# %%
pd.concat([df_a, df_b], axis=1)
# Out:
#   subject_id first_name last_name subject_id first_name last_name
# 0          1       Alex  Anderson          4      Billy    Bonder
# 1          2        Amy  Ackerman          5      Brian     Black
# 2          3      Allen       Ali          6       Bran   Balwner
# 3          4      Alice      Aoni          7      Bryce     Brice
# 4          5     Ayoung   Atiches          8      Betty    Btisan

# %% [markdown]
# # Merge таблиц по subject_id

# %%
pd.merge(df_new, df_n, on='subject_id')
# Out:
#   subject_id first_name last_name  test_id
# 0          1       Alex  Anderson       51
# 1          2        Amy  Ackerman       15
# 2          3      Allen       Ali       15
# 3          4      Alice      Aoni       61
# 4          4      Billy    Bonder       61
# 5          5     Ayoung   Atiches       16
# 6          5      Brian     Black       16
# 7          7      Bryce     Brice       14
# 8          8      Betty    Btisan       15

# %% [markdown]
# # Merge таблиц по subject_id в левой таблице и subject_id в правой

# %%
pd.merge(df_new, df_n, left_on='subject_id', right_on='subject_id')
# Out:
#   subject_id first_name last_name  test_id
# 0          1       Alex  Anderson       51
# 1          2        Amy  Ackerman       15
# 2          3      Allen       Ali       15
# 3          4      Alice      Aoni       61
# 4          4      Billy    Bonder       61
# 5          5     Ayoung   Atiches       16
# 6          5      Brian     Black       16
# 7          7      Bryce     Brice       14
# 8          8      Betty    Btisan       15

# %% [markdown]
# # Outer join

# %% [markdown]
# Внешнее соединение

# %%
pd.merge(df_a, df_b, on='subject_id', how='outer')
# Out:
#   subject_id first_name_x last_name_x first_name_y last_name_y
# 0          1         Alex    Anderson          NaN         NaN
# 1          2          Amy    Ackerman          NaN         NaN
# 2          3        Allen         Ali          NaN         NaN
# 3          4        Alice        Aoni        Billy      Bonder
# 4          5       Ayoung     Atiches        Brian       Black
# 5          6          NaN         NaN         Bran     Balwner
# 6          7          NaN         NaN        Bryce       Brice
# 7          8          NaN         NaN        Betty      Btisan

# %% [markdown]
# # Inner join

# %% [markdown]
# Объединение только по пересекающимся значениям ключевого поля

# %%
pd.merge(df_a, df_b, on='subject_id', how='inner')
# Out:
#   subject_id first_name_x last_name_x first_name_y last_name_y
# 0          4        Alice        Aoni        Billy      Bonder
# 1          5       Ayoung     Atiches        Brian       Black

# %% [markdown]
# # Right join

# %%
pd.merge(df_a, df_b, on='subject_id', how='right')
# Out:
#   subject_id first_name_x last_name_x first_name_y last_name_y
# 0          4        Alice        Aoni        Billy      Bonder
# 1          5       Ayoung     Atiches        Brian       Black
# 2          6          NaN         NaN         Bran     Balwner
# 3          7          NaN         NaN        Bryce       Brice
# 4          8          NaN         NaN        Betty      Btisan

# %% [markdown]
# # Left join

# %%
pd.merge(df_a, df_b, on='subject_id', how='left')
# Out:
#   subject_id first_name_x last_name_x first_name_y last_name_y
# 0          1         Alex    Anderson          NaN         NaN
# 1          2          Amy    Ackerman          NaN         NaN
# 2          3        Allen         Ali          NaN         NaN
# 3          4        Alice        Aoni        Billy      Bonder
# 4          5       Ayoung     Atiches        Brian       Black

# %% [markdown]
# ![join-or-merge-in-python-pandas.png](attachment:join-or-merge-in-python-pandas.png)

# %% [markdown]
# ### Добавление суффикса к названию столбца

# %%
pd.merge(df_a, df_b, on='subject_id', how='left', suffixes=('_left', '_right'))
# Out:
#   subject_id first_name_left last_name_left first_name_right last_name_right
# 0          1            Alex       Anderson              NaN             NaN
# 1          2             Amy       Ackerman              NaN             NaN
# 2          3           Allen            Ali              NaN             NaN
# 3          4           Alice           Aoni            Billy          Bonder
# 4          5          Ayoung        Atiches            Brian           Black

# %% [markdown]
# ### Использование индексов при join-е

# %%
pd.merge(df_a, df_b, right_index=True, left_index=True)
# Out:
#   subject_id_x first_name_x last_name_x subject_id_y first_name_y last_name_y
# 0            1         Alex    Anderson            4        Billy      Bonder
# 1            2          Amy    Ackerman            5        Brian       Black
# 2            3        Allen         Ali            6         Bran     Balwner
# 3            4        Alice        Aoni            7        Bryce       Brice
# 4            5       Ayoung     Atiches            8        Betty      Btisan
