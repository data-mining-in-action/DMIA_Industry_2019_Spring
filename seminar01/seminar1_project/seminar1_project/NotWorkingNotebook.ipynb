# %%
from seminar1_project.module import cool_function_plus_one
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-daeed55b90ef> in <module>
# ----> 1 from seminar1_project.module import cool_function_plus_one
#
# ModuleNotFoundError: No module named 'seminar1_project'

# %%
cool_function_plus_one(0)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-c5332137854d> in <module>
# ----> 1 cool_function_plus_one(0)
#
# NameError: name 'cool_function_plus_one' is not defined
